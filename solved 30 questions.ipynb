# %% [markdown]
# <a href="https://colab.research.google.com/github/N0De-SaiNi/data-science-lab-exp01/blob/main/solved%2030%20questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1
import pandas as pd
sales = pd.Series([120,150,180,210])
print(sales)
# Out:
# 0    120
# 1    150
# 2    180
# 3    210
# dtype: int64

# %%
2
marks = pd.Series([72,81,69,90])
marks.values
# Out:
# array([72, 81, 69, 90])

# %%
3
marks.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
4
temperature = pd.Series([28,31,30,29], index=['Mon','Tue','Wed','Thu'])
print(temperature)
# Out:
# Mon    28
# Tue    31
# Wed    30
# Thu    29
# dtype: int64

# %%
5
population = pd.Series([35, 42, 31], index=['Delhi','Mumbai','Jaipur'])
population['Jaipur']
# Out:
# np.int64(31)

# %%
6
score = pd.Series([35,68,44,79,52])
score [score > 50]
# Out:
# 1    68
# 3    79
# 4    52
# dtype: int64

# %%
7
subjects = pd.Series([76,83,91], index=['Physics','Chemistry','Maths'])
'Chemistry' in subjects.index
# Out:
# True

# %%
8
series = pd.Series([10,20,30,40])
series.to_dict()
# Out:
# {0: 10, 1: 20, 2: 30, 3: 40}

# %%
9
price = {'Pen': 10,'Notebook': 55,'Bag': 700}
price_series = pd.Series(series)
print (series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# 10
# Dictionary keys become the Series index.

# %%
11
data ={'A': 10,'B':20,'C':30}
s = pd.Series(data, index=['A','B','C','D'])
s.isna()
# Out:
# A    False
# B    False
# C    False
# D     True
# dtype: bool

# %%
12
s.isnull()
# Out:
# A    False
# B    False
# C    False
# D     True
# dtype: bool

# %%
13
s.notnull()
# Out:
# A     True
# B     True
# C     True
# D    False
# dtype: bool

# %%
14
sales.name = 'Monthly Sales'

# %%
15
sales.indexname = 'Monthly '

# %%
16
s = pd.Series([18, 45, 27, 61], index=['P','Q','R','S'])
s[s > 30]
# Out:
# Q    45
# S    61
# dtype: int64

# %%
17
s = pd.Series([500,600,700], index = ['East','West','North'])
print('West'in s)
print(500 in s)
# Out:
# True
# False

# %%
18
import pandas as pd

city_data = {'Delhi': 80, 'Pune': 65, 'Kochi': 70}

s = pd.Series(city_data, index=['Delhi', 'Kochi', 'Pune', 'Chennai'])

print(s)
# Out:
# Delhi      80.0
# Kochi      70.0
# Pune       65.0
# Chennai     NaN
# dtype: float64

# %%
19
import pandas as pd

s = pd.Series({'W': 5, 'X': 10, 'Y': 15},
              index=['W', 'X', 'Y', 'Z'])

print(pd.isnull(s))
# Out:
# W    False
# X    False
# Y    False
# Z     True
# dtype: bool

# %%
20
import pandas as pd

s = pd.Series({'W': 5, 'X': 10, 'Y': 15},
              index=['W', 'X', 'Y', 'Z'])

print(pd.notnull(s))
# Out:
# W     True
# X     True
# Y     True
# Z    False
# dtype: bool

# %%
21
import pandas as pd

s1 = pd.Series([10, 20, 30], index=['A', 'B', 'C'])
s2 = pd.Series([1, 2, 3], index=['C', 'A', 'B'])

print(s1 + s2)
# Out:
# A    12
# B    23
# C    31
# dtype: int64

# %%
22
import pandas as pd

s1 = pd.Series({'A': 12, 'B': 18})
s2 = pd.Series({'B': 5, 'C': 9})

print(s1 + s2)
# Out:
# A     NaN
# B    23.0
# C     NaN
# dtype: float64

# %%
23
import pandas as pd

stock = pd.Series([25, 40, 18],
                  index=['Item1', 'Item2', 'Item3'])

stock_dict = stock.to_dict()

stock2 = pd.Series(stock_dict)

print(stock_dict)
print(stock2)
# Out:
# {'Item1': 25, 'Item2': 40, 'Item3': 18}
# Item1    25
# Item2    40
# Item3    18
# dtype: int64

# %%
24
import pandas as pd

marks = {'Maths': 88, 'Science': 74, 'English': 69, 'History': 81}

s = pd.Series(marks, index=['History', 'English', 'Science', 'Maths'])

print(s)
print(s[s > 70])
# Out:
# History    81
# English    69
# Science    74
# Maths      88
# dtype: int64
# History    81
# Science    74
# Maths      88
# dtype: int64

# %%
25
import pandas as pd

rev = pd.Series([100, 200, 300])

rev.name = 'Revenue'
rev.index.name = 'Branch'

print(rev)
# Out:
# Branch
# 0    100
# 1    200
# 2    300
# Name: Revenue, dtype: int64

# %%
26
import pandas as pd

north = pd.Series({'Jan': 40, 'Feb': 55, 'Mar': 60})
south = pd.Series({'Feb': 20, 'Mar': 25, 'Apr': 30})

total = north + south

print(total)
# Out:
# Apr     NaN
# Feb    75.0
# Jan     NaN
# Mar    85.0
# dtype: float64

# %%
27
import pandas as pd

d = {'Red': 12, 'Blue': 18, 'Green': 24}

labels = ['Green', 'Red', 'Yellow', 'Blue']

result = pd.Series(d, index=labels)

print(result)
print(pd.isnull(result))
# Out:
# Green     24.0
# Red       12.0
# Yellow     NaN
# Blue      18.0
# dtype: float64
# Green     False
# Red       False
# Yellow     True
# Blue      False
# dtype: bool

# %%
28
import pandas as pd

s = pd.Series([90, 75, 82], index=['Ravi', 'Aman', 'Neha'])

d = s.to_dict()

s2 = pd.Series(d)

print(d)
print(s2)
# Out:
# {'Ravi': 90, 'Aman': 75, 'Neha': 82}
# Ravi    90
# Aman    75
# Neha    82
# dtype: int64

# %%
29
import pandas as pd

sales = pd.Series(
    [600, 450, 750, 300],
    index=['Laptop', 'Mouse', 'Phone', 'Keyboard']
)

print(sales)

# Select one label
print(sales['Phone'])

# Filter sales above 500
print(sales[sales > 500])

# Check whether a label exists
print('Laptop' in sales.index)

# Convert Series to dictionary
sales_dict = sales.to_dict()
print(sales_dict)
# Out:
# Laptop      600
# Mouse       450
# Phone       750
# Keyboard    300
# dtype: int64
# 750
# Laptop    600
# Phone     750
# dtype: int64
# True
# {'Laptop': 600, 'Mouse': 450, 'Phone': 750, 'Keyboard': 300}

# %%
30
import pandas as pd

data = {'A': 15, 'B': 35, 'C': 25}

s = pd.Series(data, index=['C', 'A', 'D', 'B'])

s.name = 'Observations'
s.index.name = 'Category'

print(s)
# Out:
# Category
# C    25.0
# A    15.0
# D     NaN
# B    35.0
# Name: Observations, dtype: float64
